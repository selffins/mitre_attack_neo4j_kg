# %% [markdown]
# # Building a Neo4j Knowledge Graph for MITRE ATT&CK
#
# Loosely adapted from https://graphacademy.neo4j.com/courses/llm-knowledge-graph-construction/
# We do a lot of data importing and cleaning
#
#
# # Tactics
#
# We use pandas for checking and cleaning the data, and openpyxl for reading .xlsx files.

# %%
# !pip3 install pandas
# !pip3 install openpyxl

# %%
# !ls
# Out:
# clean  csv  neo4j.pw  notebook.ipynb  xlsx

# %%
# !ls ./xlsx
# Out:
# enterprise-attack-v16.1-campaigns.xlsx
# enterprise-attack-v16.1-datasources.xlsx
# enterprise-attack-v16.1-groups.xlsx
# enterprise-attack-v16.1-matrices.xlsx
# enterprise-attack-v16.1-mitigations.xlsx
# enterprise-attack-v16.1-relationships.xlsx
# enterprise-attack-v16.1-software.xlsx
# enterprise-attack-v16.1-tactics.xlsx
# enterprise-attack-v16.1-techniques.xlsx

# %%
import pandas as pd

# %%
with pd.ExcelFile("./xlsx/enterprise-attack-v16.1-tactics.xlsx") as xls:  
    tactics = pd.read_excel(xls)
    print(xls.sheet_names)
    # Only one sheet.
# Out:
# ['tactics']

# %%
tactics.head()
# Out:
#        ID                                            STIX ID  \
# 0  TA0009  x-mitre-tactic--d108ce10-2419-4cf9-a774-46161d...
# 1  TA0011  x-mitre-tactic--f72804c5-f15a-449e-a5da-2eecd1...
# 2  TA0006  x-mitre-tactic--2558fd61-8c75-4730-94c4-11926d...
# 3  TA0005  x-mitre-tactic--78b23412-0651-46d7-a540-170a1c...
# 4  TA0007  x-mitre-tactic--c17c5845-175e-4421-9713-829d05...
#
#                   name                                        description  \
# 0           Collection  The adversary is trying to gather data of inte...
# 1  Command and Control  The adversary is trying to communicate with co...
# 2    Credential Access  The adversary is trying to steal account names...
# 3      Defense Evasion  The adversary is trying to avoid being detecte...
# 4            Discovery  The adversary is trying to figure out your env...
#
#                                        url          created  \
# 0  https://attack.mitre.org/tactics/TA0009  17 October 2018
# 1  https://attack.mitre.org/tactics/TA0011  17 October 2018
# 2  https://attack.mitre.org/tactics/TA0006  17 October 2018
# 3  https://attack.mitre.org/tactics/TA0005  17 October 2018
# 4  https://attack.mitre.org/tactics/TA0007  17 October 2018
#
#        last modified             domain  version
# 0  05 September 2024  enterprise-attack      1.1
# 1       19 July 2019  enterprise-attack      1.0
# 2       19 July 2019  enterprise-attack      1.0
# 3       19 July 2019  enterprise-attack      1.0
# 4       19 July 2019  enterprise-attack      1.0

# %% [markdown]
# We only care about: ID, name, description

# %%
tactics = tactics.drop(columns=["STIX ID", "url", "domain", "version", "last modified", "created"])

# %% [markdown]
# Write to ./clean/

# %%
with open("./clean/tactics-tactics.csv", mode="w") as f:
    f.write(tactics.to_csv(index='False'))

# %% [markdown]
# Check

# %% [markdown]
# # Techniques

# %%
xls = pd.ExcelFile("./xlsx/enterprise-attack-v16.1-techniques.xlsx")
print(xls.sheet_names)
# Out:
# ['techniques', 'procedure examples', 'associated mitigations', 'citations']

# %% [markdown]
# Four sheets: techniques, procedure examples, associated mitigations, citations

# %% [markdown]
# ### Techniques Inspection and Cleaning

# %%
techniques_techniques = pd.read_excel(xls, sheet_name='techniques')

# %%
techniques_techniques.head()
# Out:
#           ID                                            STIX ID  \
# 0      T1548  attack-pattern--67720091-eee3-4d2d-ae16-826456...
# 1  T1548.002  attack-pattern--120d5519-3098-4e1c-9191-2aa612...
# 2  T1548.004  attack-pattern--b84903f0-c7d5-435d-a69e-de47cc...
# 3  T1548.001  attack-pattern--6831414d-bb70-42b7-8030-d4e06b...
# 4  T1548.003  attack-pattern--1365fe3b-0f50-455d-b4da-266ce3...
#
#                                                 name  \
# 0                  Abuse Elevation Control Mechanism
# 1  Abuse Elevation Control Mechanism: Bypass User...
# 2  Abuse Elevation Control Mechanism: Elevated Ex...
# 3  Abuse Elevation Control Mechanism: Setuid and ...
# 4  Abuse Elevation Control Mechanism: Sudo and Su...
#
#                                          description  \
# 0  Adversaries may circumvent mechanisms designed...
# 1  Adversaries may bypass UAC mechanisms to eleva...
# 2  Adversaries may leverage the <code>Authorizati...
# 3  An adversary may abuse configurations where an...
# 4  Adversaries may perform sudo caching and/or us...
#
#                                              url          created  \
# 0      https://attack.mitre.org/techniques/T1548  30 January 2020
# 1  https://attack.mitre.org/techniques/T1548/002  30 January 2020
# 2  https://attack.mitre.org/techniques/T1548/004  30 January 2020
# 3  https://attack.mitre.org/techniques/T1548/001  30 January 2020
# 4  https://attack.mitre.org/techniques/T1548/003  30 January 2020
#
#      last modified             domain  version  \
# 0  15 October 2024  enterprise-attack      1.4
# 1    21 April 2023  enterprise-attack      2.1
# 2  19 October 2022  enterprise-attack      1.0
# 3    15 March 2023  enterprise-attack      1.1
# 4    14 March 2022  enterprise-attack      1.0
#
#                                  tactics  ... is sub-technique  \
# 0  Defense Evasion, Privilege Escalation  ...            False
# 1  Defense Evasion, Privilege Escalation  ...             True
# 2  Defense Evasion, Privilege Escalation  ...             True
# 3  Defense Evasion, Privilege Escalation  ...             True
# 4  Defense Evasion, Privilege Escalation  ...             True
#
#   sub-technique of             defenses bypassed  \
# 0              NaN                           NaN
# 1            T1548  Windows User Account Control
# 2            T1548                           NaN
# 3            T1548                           NaN
# 4            T1548                           NaN
#
#                                         contributors permissions required  \
# 0                                                NaN  Administrator, User
# 1                        Casey Smith; Stefan Kanthak  Administrator, User
# 2  Erika Noerenberg, @gutterchurl, Carbon Black; ...  Administrator, User
# 3                                                NaN                 User
# 4                                                NaN                 User
#
#   supports remote system requirements impact type  effective permissions  \
# 0             NaN                 NaN         NaN                    NaN
# 1             NaN                 NaN         NaN          Administrator
# 2             NaN                 NaN         NaN                   root
# 3             NaN                 NaN         NaN                    NaN
# 4             NaN                 NaN         NaN                   root
#
#                               relationship citations
# 0  (Citation: TrendMicro RaspberryRobin 2022),(Ci...
# 1  (Citation: McAfee Honeybee),(Citation: BitDefe...
# 2         (Citation: Carbon Black Shlayer Feb 2019),
# 3  (Citation: OSX Keydnap malware),(Citation: ANS...
# 4  (Citation: hexed osx.dok analysis 2019),(Citat...
#
# [5 rows x 23 columns]

# %%
techniques_techniques = techniques_techniques.drop(columns=['STIX ID', 'url', 'created', 'last modified', 'domain', 'version', 'contributors', 'relationship citations'])

# %%
techniques_techniques.columns
# Out:
# Index(['ID', 'name', 'description', 'tactics', 'detection', 'platforms',
#        'data sources', 'is sub-technique', 'sub-technique of',
#        'defenses bypassed', 'permissions required', 'supports remote',
#        'system requirements', 'impact type', 'effective permissions'],
#       dtype='object')

# %% [markdown]
# ### The annoying thing is that we have "is sub-technique", and "sub-technique of", so we need to make a dataframe for subtechniques and a dataframe for techniques proper

# %%
subtechniques_df = techniques_techniques[techniques_techniques["is sub-technique"] == True]

# %%
techniques_df = techniques_techniques[techniques_techniques["is sub-technique"] != True]

# %%
subtechniques_df.count()
# Out:
# ID                       453
# name                     453
# description              453
# tactics                  453
# detection                390
# platforms                453
# data sources             419
# is sub-technique         453
# sub-technique of         453
# defenses bypassed         72
# permissions required     104
# supports remote           23
# system requirements       23
# impact type               18
# effective permissions     15
# dtype: int64

# %%
techniques_df.count()
# Out:
# ID                       203
# name                     203
# description              203
# tactics                  203
# detection                193
# platforms                203
# data sources             197
# is sub-technique         203
# sub-technique of           0
# defenses bypassed         32
# permissions required      18
# supports remote           14
# system requirements       13
# impact type               14
# effective permissions      4
# dtype: int64

# %%
techniques_techniques.count()
# Out:
# ID                       656
# name                     656
# description              656
# tactics                  656
# detection                583
# platforms                656
# data sources             616
# is sub-technique         656
# sub-technique of         453
# defenses bypassed        104
# permissions required     122
# supports remote           37
# system requirements       36
# impact type               32
# effective permissions     19
# dtype: int64

# %%
453 + 203
# Out:
# 656

# %% [markdown]
# ### Check columns again

# %%
techniques_df.head()
# Out:
#        ID                               name  \
# 0   T1548  Abuse Elevation Control Mechanism
# 7   T1134          Access Token Manipulation
# 13  T1531             Account Access Removal
# 14  T1087                  Account Discovery
# 19  T1098               Account Manipulation
#
#                                           description  \
# 0   Adversaries may circumvent mechanisms designed...
# 7   Adversaries may modify access tokens to operat...
# 13  Adversaries may interrupt availability of syst...
# 14  Adversaries may attempt to get a listing of va...
# 19  Adversaries may manipulate accounts to maintai...
#
#                                   tactics  \
# 0   Defense Evasion, Privilege Escalation
# 7   Defense Evasion, Privilege Escalation
# 13                                 Impact
# 14                              Discovery
# 19      Persistence, Privilege Escalation
#
#                                             detection  \
# 0   Monitor the file system for files that have th...
# 7   If an adversary is using a standard command-li...
# 13  Use process monitoring to monitor the executio...
# 14  System and network discovery techniques normal...
# 19  Collect events that correlate with changes to ...
#
#                                             platforms  \
# 0   IaaS, Identity Provider, Linux, Office Suite, ...
# 7                                             Windows
# 13    IaaS, Linux, Office Suite, SaaS, Windows, macOS
# 14  IaaS, Identity Provider, Linux, Office Suite, ...
# 19  Containers, IaaS, Identity Provider, Linux, Ne...
#
#                                          data sources  is sub-technique  \
# 0   Command: Command Execution, File: File Metadat...             False
# 7   Active Directory: Active Directory Object Modi...             False
# 13  Active Directory: Active Directory Object Modi...             False
# 14  Command: Command Execution, File: File Access,...             False
# 19  Active Directory: Active Directory Object Modi...             False
#
#    sub-technique of                                  defenses bypassed  \
# 0               NaN                                                NaN
# 7               NaN  Heuristic Detection, Host Forensic Analysis, S...
# 13              NaN                                                NaN
# 14              NaN                                                NaN
# 19              NaN                                                NaN
#
#    permissions required  supports remote system requirements   impact type  \
# 0   Administrator, User              NaN                 NaN           NaN
# 7   Administrator, User              NaN                 NaN           NaN
# 13                  NaN              NaN                 NaN  Availability
# 14                  NaN              NaN                 NaN           NaN
# 19                  NaN              NaN                 NaN           NaN
#
#    effective permissions
# 0                    NaN
# 7                 SYSTEM
# 13                   NaN
# 14                   NaN
# 19                   NaN

# %% [markdown]
# ### The columns: `supports remote, system requirements, impact type, effective permissions` have too many NaN, so we drop them :]

# %%
techniques_df = techniques_df.drop(columns=['supports remote','system requirements', 'impact type', 'effective permissions'])

# %%
subtechniques_df = subtechniques_df.drop(columns=['supports remote','system requirements', 'impact type', 'effective permissions'])

# %%
techniques_df.head()
# Out:
#        ID                               name  \
# 0   T1548  Abuse Elevation Control Mechanism
# 7   T1134          Access Token Manipulation
# 13  T1531             Account Access Removal
# 14  T1087                  Account Discovery
# 19  T1098               Account Manipulation
#
#                                           description  \
# 0   Adversaries may circumvent mechanisms designed...
# 7   Adversaries may modify access tokens to operat...
# 13  Adversaries may interrupt availability of syst...
# 14  Adversaries may attempt to get a listing of va...
# 19  Adversaries may manipulate accounts to maintai...
#
#                                   tactics  \
# 0   Defense Evasion, Privilege Escalation
# 7   Defense Evasion, Privilege Escalation
# 13                                 Impact
# 14                              Discovery
# 19      Persistence, Privilege Escalation
#
#                                             detection  \
# 0   Monitor the file system for files that have th...
# 7   If an adversary is using a standard command-li...
# 13  Use process monitoring to monitor the executio...
# 14  System and network discovery techniques normal...
# 19  Collect events that correlate with changes to ...
#
#                                             platforms  \
# 0   IaaS, Identity Provider, Linux, Office Suite, ...
# 7                                             Windows
# 13    IaaS, Linux, Office Suite, SaaS, Windows, macOS
# 14  IaaS, Identity Provider, Linux, Office Suite, ...
# 19  Containers, IaaS, Identity Provider, Linux, Ne...
#
#                                          data sources  is sub-technique  \
# 0   Command: Command Execution, File: File Metadat...             False
# 7   Active Directory: Active Directory Object Modi...             False
# 13  Active Directory: Active Directory Object Modi...             False
# 14  Command: Command Execution, File: File Access,...             False
# 19  Active Directory: Active Directory Object Modi...             False
#
#    sub-technique of                                  defenses bypassed  \
# 0               NaN                                                NaN
# 7               NaN  Heuristic Detection, Host Forensic Analysis, S...
# 13              NaN                                                NaN
# 14              NaN                                                NaN
# 19              NaN                                                NaN
#
#    permissions required
# 0   Administrator, User
# 7   Administrator, User
# 13                  NaN
# 14                  NaN
# 19                  NaN

# %%
techniques_df.drop(columns=['is sub-technique', 'sub-technique of'])
# Out:
#         ID                                name  \
# 0    T1548   Abuse Elevation Control Mechanism
# 7    T1134           Access Token Manipulation
# 13   T1531              Account Access Removal
# 14   T1087                   Account Discovery
# 19   T1098                Account Manipulation
# ..     ...                                 ...
# 643  T1497      Virtualization/Sandbox Evasion
# 647  T1600                   Weaken Encryption
# 650  T1102                         Web Service
# 654  T1047  Windows Management Instrumentation
# 655  T1220               XSL Script Processing
#
#                                            description  \
# 0    Adversaries may circumvent mechanisms designed...
# 7    Adversaries may modify access tokens to operat...
# 13   Adversaries may interrupt availability of syst...
# 14   Adversaries may attempt to get a listing of va...
# 19   Adversaries may manipulate accounts to maintai...
# ..                                                 ...
# 643  Adversaries may employ various means to detect...
# 647  Adversaries may compromise a network device’s ...
# 650  Adversaries may use an existing, legitimate ex...
# 654  Adversaries may abuse Windows Management Instr...
# 655  Adversaries may bypass application control and...
#
#                                    tactics  \
# 0    Defense Evasion, Privilege Escalation
# 7    Defense Evasion, Privilege Escalation
# 13                                  Impact
# 14                               Discovery
# 19       Persistence, Privilege Escalation
# ..                                     ...
# 643             Defense Evasion, Discovery
# 647                        Defense Evasion
# 650                    Command and Control
# 654                              Execution
# 655                        Defense Evasion
#
#                                              detection  \
# 0    Monitor the file system for files that have th...
# 7    If an adversary is using a standard command-li...
# 13   Use process monitoring to monitor the executio...
# 14   System and network discovery techniques normal...
# 19   Collect events that correlate with changes to ...
# ..                                                 ...
# 643  Virtualization, sandbox, user activity, and re...
# 647  There is no documented method for defenders to...
# 650  Host data that can relate unknown or suspiciou...
# 654  Monitor network traffic for WMI connections; t...
# 655  Use process monitoring to monitor the executio...
#
#                                              platforms  \
# 0    IaaS, Identity Provider, Linux, Office Suite, ...
# 7                                              Windows
# 13     IaaS, Linux, Office Suite, SaaS, Windows, macOS
# 14   IaaS, Identity Provider, Linux, Office Suite, ...
# 19   Containers, IaaS, Identity Provider, Linux, Ne...
# ..                                                 ...
# 643                              Linux, Windows, macOS
# 647                                            Network
# 650                              Linux, Windows, macOS
# 654                                            Windows
# 655                                            Windows
#
#                                           data sources  \
# 0    Command: Command Execution, File: File Metadat...
# 7    Active Directory: Active Directory Object Modi...
# 13   Active Directory: Active Directory Object Modi...
# 14   Command: Command Execution, File: File Access,...
# 19   Active Directory: Active Directory Object Modi...
# ..                                                 ...
# 643  Command: Command Execution, Process: OS API Ex...
# 647                            File: File Modification
# 650  Network Traffic: Network Connection Creation, ...
# 654  Command: Command Execution, Network Traffic: N...
# 655     Module: Module Load, Process: Process Creation
#
#                                      defenses bypassed permissions required
# 0                                                  NaN  Administrator, User
# 7    Heuristic Detection, Host Forensic Analysis, S...  Administrator, User
# 13                                                 NaN                  NaN
# 14                                                 NaN                  NaN
# 19                                                 NaN                  NaN
# ..                                                 ...                  ...
# 643  Anti-virus, Host forensic analysis, Signature-...                  NaN
# 647                                         Encryption        Administrator
# 650                                                NaN                  NaN
# 654                                                NaN                  NaN
# 655  Anti-virus, Application Control, Digital Certi...                  NaN
#
# [203 rows x 9 columns]

# %% [markdown]
# ## Creating a subtechniques relationship table

# %%
subtechniques_relationship = subtechniques_df[["ID", "sub-technique of"]].rename(
    columns={"ID": "subtechnique_id", "subtechnique_of": "parent_technique_id"}
)

subtechniques_relationship["relationship"] = "sub-technique"

# %%
subtechniques_relationship.head()
# Out:
#   subtechnique_id sub-technique of   relationship
# 1       T1548.002            T1548  sub-technique
# 2       T1548.004            T1548  sub-technique
# 3       T1548.001            T1548  sub-technique
# 4       T1548.003            T1548  sub-technique
# 5       T1548.006            T1548  sub-technique

# %%
subtechniques_relationship.count()
# Out:
# subtechnique_id     453
# sub-technique of    453
# relationship        453
# dtype: int64

# %% [markdown]
# ## Final changes to subtechniques_df. Note that we could have kept the "tactics" column but for hierarchy purposes we remove it. And data sources is in relationships.xlsx so we don't care for now

# %%
subtechniques_df = subtechniques_df.drop(columns=["tactics", "is sub-technique", "sub-technique of", "data sources"])

# %%
subtechniques_df.head()
# Out:
#           ID                                               name  \
# 1  T1548.002  Abuse Elevation Control Mechanism: Bypass User...
# 2  T1548.004  Abuse Elevation Control Mechanism: Elevated Ex...
# 3  T1548.001  Abuse Elevation Control Mechanism: Setuid and ...
# 4  T1548.003  Abuse Elevation Control Mechanism: Sudo and Su...
# 5  T1548.006  Abuse Elevation Control Mechanism: TCC Manipul...
#
#                                          description  \
# 1  Adversaries may bypass UAC mechanisms to eleva...
# 2  Adversaries may leverage the <code>Authorizati...
# 3  An adversary may abuse configurations where an...
# 4  Adversaries may perform sudo caching and/or us...
# 5  Adversaries can manipulate or abuse the Transp...
#
#                                            detection     platforms  \
# 1  There are many ways to perform UAC bypasses wh...       Windows
# 2  Consider monitoring for <code>/usr/libexec/sec...         macOS
# 3  Monitor the file system for files that have th...  Linux, macOS
# 4  On Linux, auditd can alert every time a user's...  Linux, macOS
# 5                                                NaN         macOS
#
#               defenses bypassed permissions required
# 1  Windows User Account Control  Administrator, User
# 2                           NaN  Administrator, User
# 3                           NaN                 User
# 4                           NaN                 User
# 5                           NaN                  NaN

# %% [markdown]
# ## Save :)

# %%
with open("./clean/subtechniques.csv", "w") as f:
    f.write(subtechniques_df.to_csv(index='False'))

# %%
with open("./clean/subtechniques_relationship.csv", "w") as f:
    f.write(subtechniques_relationship.to_csv(index='False'))

# %% [markdown]
# ### TODO: platforms, data sources, defenses bypassed, permissions required - make relationship tables
# ### For now we keep in csv but ignore when importing to neo4j

# %% [markdown]
# ## Creating a tactics-techniques relationship table. Notice how "tactics" is a list :D

# %%
techniques_df.head()
# Out:
#        ID                               name  \
# 0   T1548  Abuse Elevation Control Mechanism
# 7   T1134          Access Token Manipulation
# 13  T1531             Account Access Removal
# 14  T1087                  Account Discovery
# 19  T1098               Account Manipulation
#
#                                           description  \
# 0   Adversaries may circumvent mechanisms designed...
# 7   Adversaries may modify access tokens to operat...
# 13  Adversaries may interrupt availability of syst...
# 14  Adversaries may attempt to get a listing of va...
# 19  Adversaries may manipulate accounts to maintai...
#
#                                   tactics  \
# 0   Defense Evasion, Privilege Escalation
# 7   Defense Evasion, Privilege Escalation
# 13                                 Impact
# 14                              Discovery
# 19      Persistence, Privilege Escalation
#
#                                             detection  \
# 0   Monitor the file system for files that have th...
# 7   If an adversary is using a standard command-li...
# 13  Use process monitoring to monitor the executio...
# 14  System and network discovery techniques normal...
# 19  Collect events that correlate with changes to ...
#
#                                             platforms  \
# 0   IaaS, Identity Provider, Linux, Office Suite, ...
# 7                                             Windows
# 13    IaaS, Linux, Office Suite, SaaS, Windows, macOS
# 14  IaaS, Identity Provider, Linux, Office Suite, ...
# 19  Containers, IaaS, Identity Provider, Linux, Ne...
#
#                                          data sources  is sub-technique  \
# 0   Command: Command Execution, File: File Metadat...             False
# 7   Active Directory: Active Directory Object Modi...             False
# 13  Active Directory: Active Directory Object Modi...             False
# 14  Command: Command Execution, File: File Access,...             False
# 19  Active Directory: Active Directory Object Modi...             False
#
#    sub-technique of                                  defenses bypassed  \
# 0               NaN                                                NaN
# 7               NaN  Heuristic Detection, Host Forensic Analysis, S...
# 13              NaN                                                NaN
# 14              NaN                                                NaN
# 19              NaN                                                NaN
#
#    permissions required
# 0   Administrator, User
# 7   Administrator, User
# 13                  NaN
# 14                  NaN
# 19                  NaN

# %%
tactics_relationship = techniques_df.assign(tactics=techniques_df["tactics"].str.split(",")).explode("tactics")

tactics_relationship = tactics_relationship[["ID", "tactics"]].rename(
    columns={"ID": "technique_id", "tactics": "tactic_id"}
)

tactics_relationship["relationship"] = "is tactic of"

# %%
tactics_relationship.head()
# Out:
#    technique_id              tactic_id  relationship
# 0         T1548        Defense Evasion  is tactic of
# 0         T1548   Privilege Escalation  is tactic of
# 7         T1134        Defense Evasion  is tactic of
# 7         T1134   Privilege Escalation  is tactic of
# 13        T1531                 Impact  is tactic of

# %%
tactic_name_to_id = tactics.set_index("name")["ID"].to_dict()

# %%
tactics_relationship["tactic_id"] = tactics_relationship["tactic_id"].apply(
    lambda name: tactic_name_to_id[name.strip()]
)

# %%
tactics_relationship.head()
# Out:
#    technique_id tactic_id  relationship
# 0         T1548    TA0005  is tactic of
# 0         T1548    TA0004  is tactic of
# 7         T1134    TA0005  is tactic of
# 7         T1134    TA0004  is tactic of
# 13        T1531    TA0040  is tactic of

# %%
tactics_relationship.count()
# Out:
# technique_id    236
# tactic_id       236
# relationship    236
# dtype: int64

# %%
techniques_df.count()
# Out:
# ID                      203
# name                    203
# description             203
# tactics                 203
# detection               193
# platforms               203
# data sources            197
# is sub-technique        203
# sub-technique of          0
# defenses bypassed        32
# permissions required     18
# dtype: int64

# %% [markdown]
# ## Clean and save

# %%
techniques_df = techniques_df.drop(columns=["tactics", "data sources", "is sub-technique", "sub-technique of"])

# %%
techniques_df.columns
# Out:
# Index(['ID', 'name', 'description', 'detection', 'platforms',
#        'defenses bypassed', 'permissions required'],
#       dtype='object')

# %%
with open("./clean/tactics_relationship.csv", "w") as f:
    f.write(tactics_relationship.to_csv(index='False'))

# %%
with open("./clean/techniques.csv", "w") as f:
    f.write(techniques_df.to_csv(index='False'))

# %% [markdown]
# # Mitigations

# %%
# !ls ./xlsx
# Out:
# enterprise-attack-v16.1-campaigns.xlsx
# enterprise-attack-v16.1-datasources.xlsx
# enterprise-attack-v16.1-groups.xlsx
# enterprise-attack-v16.1-matrices.xlsx
# enterprise-attack-v16.1-mitigations.xlsx
# enterprise-attack-v16.1-relationships.xlsx
# enterprise-attack-v16.1-software.xlsx
# enterprise-attack-v16.1-tactics.xlsx
# enterprise-attack-v16.1-techniques.xlsx

# %%
xls = pd.ExcelFile("./xlsx/enterprise-attack-v16.1-mitigations.xlsx") 
mitigations = pd.read_excel(xls)
print(xls.sheet_names)
# Out:
# ['mitigations', 'techniques addressed', 'citations']

# %%
mitigations_df = pd.read_excel(xls, sheet_name='mitigations')
mitigations_to_techniques_df = pd.read_excel(xls, sheet_name ='techniques addressed')

# %% [markdown]
# ## Mitigations

# %%
mitigations_df.head()
# Out:
#       ID                                            STIX ID  \
# 0  M1036  course-of-action--f9f9e6ef-bc0a-41ad-ba11-0924...
# 1  M1015  course-of-action--e3388c78-2a8d-47c2-8422-c139...
# 2  M1049  course-of-action--a6a47a06-08fc-4ec4-bdc3-2037...
# 3  M1013  course-of-action--25dc1ce8-eb55-4333-ae30-a7cb...
# 4  M1048  course-of-action--b9f0c069-abbe-4a07-a245-2481...
#
#                                    name  \
# 0                  Account Use Policies
# 1        Active Directory Configuration
# 2                 Antivirus/Antimalware
# 3        Application Developer Guidance
# 4  Application Isolation and Sandboxing
#
#                                          description  \
# 0  Configure features related to account use like...
# 1  Implement robust Active Directory configuratio...
# 2  Use signatures or heuristics to detect malicio...
# 3  This mitigation describes any guidance or trai...
# 4  Restrict execution of code to a virtual enviro...
#
#                                           url          created  \
# 0  https://attack.mitre.org/mitigations/M1036     11 June 2019
# 1  https://attack.mitre.org/mitigations/M1015     06 June 2019
# 2  https://attack.mitre.org/mitigations/M1049     11 June 2019
# 3  https://attack.mitre.org/mitigations/M1013  25 October 2017
# 4  https://attack.mitre.org/mitigations/M1048     11 June 2019
#
#        last modified                           domain  version  \
# 0    21 October 2022                enterprise-attack      1.0
# 1    08 October 2024                enterprise-attack      1.2
# 2      31 March 2020                enterprise-attack      1.1
# 3  27 September 2023  enterprise-attack,mobile-attack      1.1
# 4      31 March 2020                enterprise-attack      1.1
#
#                               relationship citations
# 0  (Citation: Okta Block Anonymizing Services),(C...
# 1  (Citation: AdSecurity DCSync Sept 2015),(Citat...
# 2  (Citation: SourceForge rkhunter),(Citation: Ch...
# 3  (Citation: Comparitech Replay Attack),(Citatio...
# 4  (Citation: Windows Blogs Microsoft Edge Sandbo...

# %%
mitigations_df = mitigations_df.drop(columns=['STIX ID', 'url', 'created', 'last modified', 'domain', 'version', 'relationship citations'])

# %%
mitigations_df.head()
# Out:
#       ID                                  name  \
# 0  M1036                  Account Use Policies
# 1  M1015        Active Directory Configuration
# 2  M1049                 Antivirus/Antimalware
# 3  M1013        Application Developer Guidance
# 4  M1048  Application Isolation and Sandboxing
#
#                                          description
# 0  Configure features related to account use like...
# 1  Implement robust Active Directory configuratio...
# 2  Use signatures or heuristics to detect malicio...
# 3  This mitigation describes any guidance or trai...
# 4  Restrict execution of code to a virtual enviro...

# %%
with open("./clean/mitigations.csv", "w") as f:
    f.write(mitigations_df.to_csv(index='False'))

# %% [markdown]
# ## Mitigations to techniques relationship

# %%
mitigations_to_techniques_df.head()
# Out:
#   source ID           source name  \
# 0     M1036  Account Use Policies
# 1     M1036  Account Use Policies
# 2     M1036  Account Use Policies
# 3     M1036  Account Use Policies
# 4     M1036  Account Use Policies
#
#                                           source ref source type mapping type  \
# 0  course-of-action--f9f9e6ef-bc0a-41ad-ba11-0924...  mitigation    mitigates
# 1  course-of-action--f9f9e6ef-bc0a-41ad-ba11-0924...  mitigation    mitigates
# 2  course-of-action--f9f9e6ef-bc0a-41ad-ba11-0924...  mitigation    mitigates
# 3  course-of-action--f9f9e6ef-bc0a-41ad-ba11-0924...  mitigation    mitigates
# 4  course-of-action--f9f9e6ef-bc0a-41ad-ba11-0924...  mitigation    mitigates
#
#    target ID                                     target name  \
# 0  T1550.001                        Application Access Token
# 1      T1110                                     Brute Force
# 2  T1078.004                                  Cloud Accounts
# 3  T1110.004                             Credential Stuffing
# 4      T1621  Multi-Factor Authentication Request Generation
#
#                                           target ref target type  \
# 0  attack-pattern--f005e783-57d4-4837-88ad-dbe7fa...   technique
# 1  attack-pattern--a93494bb-4b80-4ea1-8695-3236a4...   technique
# 2  attack-pattern--f232fa7a-025c-4d43-abc7-318e81...   technique
# 3  attack-pattern--b2d03cea-aec1-45ca-9744-9ee583...   technique
# 4  attack-pattern--954a1639-f2d6-407d-aef3-491762...   technique
#
#                                  mapping description  \
# 0  Where possible, consider restricting the use o...
# 1  Set account lockout policies after a certain n...
# 2  Use conditional access policies to block login...
# 3  Set account lockout policies after a certain n...
# 4  Enable account restrictions to prevent login a...
#
#                                              STIX ID           created  \
# 0  relationship--41f072bf-ec21-4a83-bb25-6c84fce8...   16 October 2024
# 1  relationship--c1a6c86e-5d5d-4cf1-845e-1660d9c1...      13 June 2019
# 2  relationship--b93fd13f-b11b-4f4b-9d77-977e7af4...  21 February 2023
# 3  relationship--4b7e0525-1ba7-4d55-89d1-07fc9419...  20 February 2020
# 4  relationship--a09cb233-bdff-4d89-bcc3-7fb21089...     01 April 2022
#
#       last modified
# 0   16 October 2024
# 1       28 May 2024
# 2     16 March 2023
# 3       28 May 2024
# 4  21 February 2023

# %%
mitigations_to_techniques_df = mitigations_to_techniques_df.drop(columns=['source ref', 'source type', 'target ref', 'STIX ID', 'created', 'last modified'])

# %%
mitigations_to_techniques_df.head()
# Out:
#   source ID           source name mapping type  target ID  \
# 0     M1036  Account Use Policies    mitigates  T1550.001
# 1     M1036  Account Use Policies    mitigates      T1110
# 2     M1036  Account Use Policies    mitigates  T1078.004
# 3     M1036  Account Use Policies    mitigates  T1110.004
# 4     M1036  Account Use Policies    mitigates      T1621
#
#                                       target name target type  \
# 0                        Application Access Token   technique
# 1                                     Brute Force   technique
# 2                                  Cloud Accounts   technique
# 3                             Credential Stuffing   technique
# 4  Multi-Factor Authentication Request Generation   technique
#
#                                  mapping description
# 0  Where possible, consider restricting the use o...
# 1  Set account lockout policies after a certain n...
# 2  Use conditional access policies to block login...
# 3  Set account lockout policies after a certain n...
# 4  Enable account restrictions to prevent login a...

# %%
print(mitigations_to_techniques_df['mapping type'].unique())
# Out:
# ['mitigates']

# %%
print(mitigations_to_techniques_df['target type'].unique())
# Out:
# ['technique']

# %% [markdown]
# ### No need to keep "source name", "target name" then!

# %%
mitigations_to_techniques_df = mitigations_to_techniques_df.drop(columns=['source name', 'target name', 'target type', 'mapping type'])

# %%
mitigations_to_techniques_df.head()
# Out:
#   source ID  target ID                                mapping description
# 0     M1036  T1550.001  Where possible, consider restricting the use o...
# 1     M1036      T1110  Set account lockout policies after a certain n...
# 2     M1036  T1078.004  Use conditional access policies to block login...
# 3     M1036  T1110.004  Set account lockout policies after a certain n...
# 4     M1036      T1621  Enable account restrictions to prevent login a...

# %% [markdown]
# ### Seperate the mitigations-subtechniques relationship from the mitigations-techniques relationship

# %%
mitigations_to_subtechniques_df = mitigations_to_techniques_df[mitigations_to_techniques_df["target ID"].str.contains(r"\.", na=False)]
mitigations_to_techniques_df = mitigations_to_techniques_df[~mitigations_to_techniques_df["target ID"].str.contains(r"\.", na=False)]

# %%
mitigations_to_subtechniques_df.head()
# Out:
#   source ID  target ID                                mapping description
# 0     M1036  T1550.001  Where possible, consider restricting the use o...
# 2     M1036  T1078.004  Use conditional access policies to block login...
# 3     M1036  T1110.004  Set account lockout policies after a certain n...
# 5     M1036  T1110.001  Set account lockout policies after a certain n...
# 6     M1036  T1110.003  Set account lockout policies after a certain n...

# %%
mitigations_to_techniques_df.head()
# Out:
#   source ID target ID                                mapping description
# 1     M1036     T1110  Set account lockout policies after a certain n...
# 4     M1036     T1621  Enable account restrictions to prevent login a...
# 7     M1036     T1648  Where possible, consider restricting access to...
# 8     M1036     T1550  Where possible, consider restricting the use o...
# 9     M1036     T1078  Use conditional access policies to block login...

# %%
with open("./clean/mitigations_to_techniques.csv", "w") as f:
    f.write(mitigations_to_techniques_df.to_csv(index='False'))

# %%
with open("./clean/mitigations_to_subtechniques.csv", "w") as f:
    f.write(mitigations_to_subtechniques_df.to_csv(index='False'))

# %% [markdown]
# # Campaigns, Groups, Software

# %% [markdown]
# ## Campaigns

# %%
# !ls ./xlsx
# Out:
# enterprise-attack-v16.1-campaigns.xlsx
# enterprise-attack-v16.1-datasources.xlsx
# enterprise-attack-v16.1-groups.xlsx
# enterprise-attack-v16.1-matrices.xlsx
# enterprise-attack-v16.1-mitigations.xlsx
# enterprise-attack-v16.1-relationships.xlsx
# enterprise-attack-v16.1-software.xlsx
# enterprise-attack-v16.1-tactics.xlsx
# enterprise-attack-v16.1-techniques.xlsx

# %%
xls = pd.ExcelFile("./xlsx/enterprise-attack-v16.1-campaigns.xlsx") 
campaigns = pd.read_excel(xls)
print(xls.sheet_names)
# Out:
# ['campaigns', 'associated software', 'techniques used', 'attributed groups', 'citations']

# %%
campaigns_df = pd.read_excel(xls, sheet_name="campaigns")

# %%
campaigns_software_df = pd.read_excel(xls, sheet_name="associated software")
campaigns_groups_df = pd.read_excel(xls, sheet_name="attributed groups")
campaigns_techniques_df = pd.read_excel(xls, sheet_name="techniques used")

# %%
campaigns_df.head()
# Out:
#       ID                                         STIX ID  \
# 0  C0028  campaign--46421788-b6e1-4256-b351-f8beffd1afba
# 1  C0025  campaign--aa73efef-1418-4dbe-b43c-87a498e97234
# 2  C0034  campaign--df8eb785-70f8-4300-b444-277ba849083d
# 3  C0040  campaign--add4d9de-1256-4166-83b8-57087288dced
# 4  C0010  campaign--ab747e62-1bcb-479f-a26b-1cd39d413d81
#
#                                  name  \
# 0  2015 Ukraine Electric Power Attack
# 1  2016 Ukraine Electric Power Attack
# 2  2022 Ukraine Electric Power Attack
# 3                          APT41 DUST
# 4                               C0010
#
#                                          description  \
# 0  [2015 Ukraine Electric Power Attack](https://a...
# 1  [2016 Ukraine Electric Power Attack](https://a...
# 2  The [2022 Ukraine Electric Power Attack](https...
# 3  [APT41 DUST](https://attack.mitre.org/campaign...
# 4  [C0010](https://attack.mitre.org/campaigns/C00...
#
#                                         url            created  \
# 0  https://attack.mitre.org/campaigns/C0028  27 September 2023
# 1  https://attack.mitre.org/campaigns/C0025      31 March 2023
# 2  https://attack.mitre.org/campaigns/C0034      27 March 2024
# 3  https://attack.mitre.org/campaigns/C0040  16 September 2024
# 4  https://attack.mitre.org/campaigns/C0010  21 September 2022
#
#        last modified                        domain  version  \
# 0    06 October 2023  ics-attack,enterprise-attack      1.0
# 1      10 April 2023  enterprise-attack,ics-attack      1.0
# 2      10 April 2024  enterprise-attack,ics-attack      1.0
# 3  21 September 2024             enterprise-attack      1.0
# 4    04 October 2022             enterprise-attack      1.0
#
#   associated campaigns associated campaigns citations        first seen  \
# 0                  NaN                            NaN  01 December 2015
# 1                  NaN                            NaN  01 December 2016
# 2                  NaN                            NaN      01 June 2022
# 3                  NaN                            NaN   31 January 2023
# 4                  NaN                            NaN  01 December 2020
#
#                                  first seen citation         last seen  \
# 0                    (Citation: Booz Allen Hamilton)   01 January 2016
# 1  (Citation: ESET Industroyer)(Citation: Dragos ...  01 December 2016
# 2         (Citation: Mandiant-Sandworm-Ukraine-2022)   01 October 2022
# 3                (Citation: Google Cloud APT41 2024)      30 June 2024
# 4              (Citation: Mandiant UNC3890 Aug 2022)    01 August 2022
#
#                                   last seen citation contributors  \
# 0                    (Citation: Booz Allen Hamilton)          NaN
# 1  (Citation: ESET Industroyer)(Citation: Dragos ...          NaN
# 2         (Citation: Mandiant-Sandworm-Ukraine-2022)          NaN
# 3                (Citation: Google Cloud APT41 2024)          NaN
# 4              (Citation: Mandiant UNC3890 Aug 2022)          NaN
#
#                               relationship citations
# 0  (Citation: Booz Allen Hamilton),(Citation: Cha...
# 1  (Citation: Dragos Crashoverride 2018),(Citatio...
# 2  (Citation: Mandiant-Sandworm-Ukraine-2022),(Ci...
# 3  (Citation: Google Cloud APT41 2024),(Citation:...
# 4  (Citation: Mandiant UNC3890 Aug 2022),(Citatio...

# %%
cols = ['ID', 'name', 'description', 'associated campaigns', 'first seen', 'last seen']
campaigns_df = campaigns_df.loc[:, cols]

# %%
campaigns_df.head()
# Out:
#       ID                                name  \
# 0  C0028  2015 Ukraine Electric Power Attack
# 1  C0025  2016 Ukraine Electric Power Attack
# 2  C0034  2022 Ukraine Electric Power Attack
# 3  C0040                          APT41 DUST
# 4  C0010                               C0010
#
#                                          description associated campaigns  \
# 0  [2015 Ukraine Electric Power Attack](https://a...                  NaN
# 1  [2016 Ukraine Electric Power Attack](https://a...                  NaN
# 2  The [2022 Ukraine Electric Power Attack](https...                  NaN
# 3  [APT41 DUST](https://attack.mitre.org/campaign...                  NaN
# 4  [C0010](https://attack.mitre.org/campaigns/C00...                  NaN
#
#          first seen         last seen
# 0  01 December 2015   01 January 2016
# 1  01 December 2016  01 December 2016
# 2      01 June 2022   01 October 2022
# 3   31 January 2023      30 June 2024
# 4  01 December 2020    01 August 2022

# %%
campaigns_df['associated campaigns'].unique()
# Out:
# array([nan, 'Operation Interception, Operation North Star'], dtype=object)

# %% [markdown]
# #### associated_campaigns isn't very useful

# %%
campaigns_df = campaigns_df.drop(columns=['associated campaigns'])

# %% [markdown]
# ### Campaigns relationships

# %% [markdown]
# #### groups

# %%
campaigns_groups_df.head()
# Out:
#   source ID                         source name  \
# 0     C0028  2015 Ukraine Electric Power Attack
# 1     C0025  2016 Ukraine Electric Power Attack
# 2     C0034  2022 Ukraine Electric Power Attack
# 3     C0040                          APT41 DUST
# 4     C0011                               C0011
#
#                                        source ref source type   mapping type  \
# 0  campaign--46421788-b6e1-4256-b351-f8beffd1afba    campaign  attributed-to
# 1  campaign--aa73efef-1418-4dbe-b43c-87a498e97234    campaign  attributed-to
# 2  campaign--df8eb785-70f8-4300-b444-277ba849083d    campaign  attributed-to
# 3  campaign--add4d9de-1256-4166-83b8-57087288dced    campaign  attributed-to
# 4  campaign--b4e5a4a9-f3be-4631-ba8f-da6ebb067fac    campaign  attributed-to
#
#   target ID        target name  \
# 0     G0034      Sandworm Team
# 1     G0034      Sandworm Team
# 2     G0034      Sandworm Team
# 3     G0096              APT41
# 4     G0134  Transparent Tribe
#
#                                           target ref target type  \
# 0  intrusion-set--381fcf73-60f6-4ab2-9991-6af3cbc...       group
# 1  intrusion-set--381fcf73-60f6-4ab2-9991-6af3cbc...       group
# 2  intrusion-set--381fcf73-60f6-4ab2-9991-6af3cbc...       group
# 3  intrusion-set--18854f55-ac7c-4634-bd9a-352dd07...       group
# 4  intrusion-set--e44e0985-bc65-4a8f-b578-211c858...       group
#
#                                  mapping description  \
# 0  (Citation: Andy Greenberg June 2017) (Citation...
# 1  (Citation: US District Court Indictment GRU Un...
# 2  (Citation: Mandiant-Sandworm-Ukraine-2022)(Cit...
# 3  [APT41 DUST](https://attack.mitre.org/campaign...
# 4  (Citation: Cisco Talos Transparent Tribe Educa...
#
#                                              STIX ID            created  \
# 0  relationship--4d407dda-944a-4974-b1c2-0a04d2c9...  27 September 2023
# 1  relationship--90647f03-38a4-4364-a3af-53640a81...      31 March 2023
# 2  relationship--d3717846-eaab-4fde-99f6-a972dec9...      27 March 2024
# 3  relationship--31aebdb8-ce4d-4d31-a144-7a5c354b...  16 September 2024
# 4  relationship--751e795e-7c1a-4ba1-bb20-636aed02...  22 September 2022
#
#        last modified
# 0  27 September 2023
# 1      31 March 2023
# 2      10 April 2024
# 3  16 September 2024
# 4  22 September 2022

# %%
campaigns_groups_df['target type'].unique()
# Out:
# array(['group'], dtype=object)

# %%
campaigns_groups_df['mapping type'].unique()
# Out:
# array(['attributed-to'], dtype=object)

# %% [markdown]
# #### only retain ID->ID, mapping desc

# %%
cols = ['source ID', 'target ID', 'mapping description']
campaigns_groups_df = campaigns_groups_df.loc[:,cols]

# %%
campaigns_groups_df.head()
# Out:
#   source ID target ID                                mapping description
# 0     C0028     G0034  (Citation: Andy Greenberg June 2017) (Citation...
# 1     C0025     G0034  (Citation: US District Court Indictment GRU Un...
# 2     C0034     G0034  (Citation: Mandiant-Sandworm-Ukraine-2022)(Cit...
# 3     C0040     G0096  [APT41 DUST](https://attack.mitre.org/campaign...
# 4     C0011     G0134  (Citation: Cisco Talos Transparent Tribe Educa...

# %% [markdown]
# #### techniques

# %%
campaigns_techniques_df.head()
# Out:
#   source ID                         source name  \
# 0     C0028  2015 Ukraine Electric Power Attack
# 1     C0028  2015 Ukraine Electric Power Attack
# 2     C0028  2015 Ukraine Electric Power Attack
# 3     C0028  2015 Ukraine Electric Power Attack
# 4     C0028  2015 Ukraine Electric Power Attack
#
#                                        source ref source type mapping type  \
# 0  campaign--46421788-b6e1-4256-b351-f8beffd1afba    campaign         uses
# 1  campaign--46421788-b6e1-4256-b351-f8beffd1afba    campaign         uses
# 2  campaign--46421788-b6e1-4256-b351-f8beffd1afba    campaign         uses
# 3  campaign--46421788-b6e1-4256-b351-f8beffd1afba    campaign         uses
# 4  campaign--46421788-b6e1-4256-b351-f8beffd1afba    campaign         uses
#
#    target ID               target name  \
# 0  T1562.001   Disable or Modify Tools
# 1  T1136.002            Domain Account
# 2      T1133  External Remote Services
# 3  T1070.004             File Deletion
# 4      T1105     Ingress Tool Transfer
#
#                                           target ref target type  \
# 0  attack-pattern--ac08589e-ee59-4935-8667-d845e3...   technique
# 1  attack-pattern--7610cada-1499-41a4-b3dd-46467b...   technique
# 2  attack-pattern--10d51417-ee35-4589-b1ff-b6df1c...   technique
# 3  attack-pattern--d63a3fb8-9452-4e9d-a60a-54be68...   technique
# 4  attack-pattern--e6919abc-99f9-4c6c-95a5-14761e...   technique
#
#                                  mapping description  \
# 0  During the [2015 Ukraine Electric Power Attack...
# 1  During the [2015 Ukraine Electric Power Attack...
# 2  During the [2015 Ukraine Electric Power Attack...
# 3  During the [2015 Ukraine Electric Power Attack...
# 4  During the [2015 Ukraine Electric Power Attack...
#
#                                              STIX ID            created  \
# 0  relationship--f53b248d-da29-4805-b714-29db3ce9...    04 October 2023
# 1  relationship--8a14f269-467e-49f8-a53f-ba1ad7fe...  27 September 2023
# 2  relationship--62ed20e9-07e5-4e22-a8dd-b93ab897...  27 September 2023
# 3  relationship--4d9acf03-bd3e-458b-bcea-6d1b5767...  27 September 2023
# 4  relationship--7d12ca01-c979-4fdf-8548-9da12c10...  27 September 2023
#
#        last modified
# 0    04 October 2023
# 1  27 September 2023
# 2  27 September 2023
# 3    02 October 2023
# 4  27 September 2023

# %%
cols = ['source ID', 'target ID', 'mapping description']
campaigns_techniques_df = campaigns_techniques_df.loc[:,cols]

# %%
campaigns_subtechniques_df = campaigns_techniques_df[campaigns_techniques_df["target ID"].str.contains(r"\.", na=False)]
campaigns_subtechniques_df.head()
# Out:
#   source ID  target ID                                mapping description
# 0     C0028  T1562.001  During the [2015 Ukraine Electric Power Attack...
# 1     C0028  T1136.002  During the [2015 Ukraine Electric Power Attack...
# 3     C0028  T1070.004  During the [2015 Ukraine Electric Power Attack...
# 5     C0028  T1056.001  During the [2015 Ukraine Electric Power Attack...
# 7     C0028  T1204.002  During the [2015 Ukraine Electric Power Attack...

# %%
campaigns_techniques_df = campaigns_techniques_df[~campaigns_techniques_df["target ID"].str.contains(r"\.", na=False)]
campaigns_techniques_df.head()
# Out:
#   source ID target ID                                mapping description
# 2     C0028     T1133  During the [2015 Ukraine Electric Power Attack...
# 4     C0028     T1105  During the [2015 Ukraine Electric Power Attack...
# 6     C0028     T1570  During the [2015 Ukraine Electric Power Attack...
# 8     C0028     T1112  During the [2015 Ukraine Electric Power Attack...
# 9     C0028     T1040  During the [2015 Ukraine Electric Power Attack...

# %%
with open("./clean/campaigns_techniques.csv", "w") as f:
    f.write(campaigns_techniques_df.to_csv(index='False'))

# %%
with open("./clean/campaigns_df.csv", "w") as f:
    f.write(campaigns_df.to_csv(index='False'))

# %%
with open("./clean/campaigns_subtechniques.csv", "w") as f:
    f.write(campaigns_subtechniques_df.to_csv(index='False'))

# %% [markdown]
# ### software

# %%
campaigns_software_df.head()
# Out:
#   source ID                         source name  \
# 0     C0028  2015 Ukraine Electric Power Attack
# 1     C0028  2015 Ukraine Electric Power Attack
# 2     C0025  2016 Ukraine Electric Power Attack
# 3     C0034  2022 Ukraine Electric Power Attack
# 4     C0040                          APT41 DUST
#
#                                        source ref source type mapping type  \
# 0  campaign--46421788-b6e1-4256-b351-f8beffd1afba    campaign         uses
# 1  campaign--46421788-b6e1-4256-b351-f8beffd1afba    campaign         uses
# 2  campaign--aa73efef-1418-4dbe-b43c-87a498e97234    campaign         uses
# 3  campaign--df8eb785-70f8-4300-b444-277ba849083d    campaign         uses
# 4  campaign--add4d9de-1256-4166-83b8-57087288dced    campaign         uses
#
#   target ID    target name                                     target ref  \
# 0     S0089    BlackEnergy  malware--54cc1d4f-5c53-4f0e-9ef5-11b4998e82e4
# 1     S0607       KillDisk  malware--e221eb77-1502-4129-af1d-fe1ad55e7ec6
# 2     S0604    Industroyer  malware--e401d4fe-f0c9-44f0-98e6-f93487678808
# 3     S0693     CaddyWiper  malware--b30d999d-64e0-4e35-9856-884e4b83d611
# 4     S0154  Cobalt Strike  malware--a7881f21-e978-4fe4-af56-92c9416a2616
#
#   target type                                mapping description  \
# 0    software                    (Citation: Booz Allen Hamilton)
# 1    software                    (Citation: Booz Allen Hamilton)
# 2    software  Within the [2016 Ukraine Electric Power Attack...
# 3    software         (Citation: Mandiant-Sandworm-Ukraine-2022)
# 4    software  [Cobalt Strike](https://attack.mitre.org/softw...
#
#                                              STIX ID            created  \
# 0  relationship--c8e78d6f-ac9d-4ad3-ae13-238f1eb4...  27 September 2023
# 1  relationship--1dad5efc-395f-4b92-8f4f-3e987a4d...  27 September 2023
# 2  relationship--57e8711a-9aae-4a22-94d4-f4c8a3a8...      31 March 2023
# 3  relationship--f0128f0b-be94-4d1e-a61e-d66cb722...      27 March 2024
# 4  relationship--55617b29-c1da-4519-87ea-97902bf3...  16 September 2024
#
#        last modified
# 0  27 September 2023
# 1  27 September 2023
# 2      07 April 2023
# 3      28 March 2024
# 4  16 September 2024

# %%
cols = ['source ID', 'target ID', 'mapping description']
campaigns_software_df = campaigns_software_df.loc[:,cols]

# %%
campaigns_software_df.head()
# Out:
#   source ID target ID                                mapping description
# 0     C0028     S0089                    (Citation: Booz Allen Hamilton)
# 1     C0028     S0607                    (Citation: Booz Allen Hamilton)
# 2     C0025     S0604  Within the [2016 Ukraine Electric Power Attack...
# 3     C0034     S0693         (Citation: Mandiant-Sandworm-Ukraine-2022)
# 4     C0040     S0154  [Cobalt Strike](https://attack.mitre.org/softw...

# %%
with open("./clean/campaigns_software.csv", "w") as f:
    f.write(campaigns_software_df.to_csv(index='False'))

# %%
## Groups

# %% [markdown]
# ## Groups

# %%
xls = pd.ExcelFile("./xlsx/enterprise-attack-v16.1-groups.xlsx") 
campaigns = pd.read_excel(xls)
print(xls.sheet_names)
# Out:
# ['groups', 'associated software', 'techniques used', 'attributed campaigns', 'citations']

# %%
groups_software_df = pd.read_excel(xls, sheet_name="associated software")
groups_campaigns_df = pd.read_excel(xls, sheet_name="attributed campaigns")
groups_techniques_df = pd.read_excel(xls, sheet_name="techniques used")
# Out:
#   Cell In[93], line 4
#     groups_df = = pd.read_excel(xls, sheet_name="groups")
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Is this redundant? Let's check
